# %% [markdown]
# # Random Forest:

# %% [markdown]
# ![My imagine](random_forest_algorithm.webp)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_excel("Raisin_Dataset.xlsx")
df.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  Perimeter    Class
# 0  87524       442.246011       253.291155      0.819738       90546  0.758651   1184.040  Kecimen
# 1  75166       406.690687       243.032436      0.801805       78789  0.684130   1121.786  Kecimen
# 2  90856       442.267048       266.328318      0.798354       93717  0.637613   1208.575  Kecimen
# 3  45928       286.540559       208.760042      0.684989       47336  0.699599    844.162  Kecimen
# 4  79408       352.190770       290.827533      0.564011       81463  0.792772   1073.251  Kecimen

# %%
# Defining Features and Target variables
X = df.drop("Class", axis = 1)
y = df["Class"]

# Train-Test Split
X_train, X_test , y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ## Using SVM:

# %%
model = SVC()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.86      0.75      0.80        83
#      Kecimen       0.81      0.90      0.85        97
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.82      0.82       180
# weighted avg       0.83      0.83      0.83       180

# %% [markdown]
# ## Using Decision Tree:

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.84      0.78      0.81        83
#      Kecimen       0.83      0.88      0.85        97
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.83      0.83       180
# weighted avg       0.83      0.83      0.83       180

# %% [markdown]
# ## Using Random Forest:

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.87      0.82      0.84        83
#      Kecimen       0.85      0.90      0.87        97
#
#     accuracy                           0.86       180
#    macro avg       0.86      0.86      0.86       180
# weighted avg       0.86      0.86      0.86       180

# %% [markdown]
# In real word scenarios data scientist tries different models and check which one performs the best and also tweakes different parameters of the model.
