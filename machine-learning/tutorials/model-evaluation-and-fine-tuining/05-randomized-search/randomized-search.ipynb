# %% [markdown]
# ### RandomizedSearchCV:
# RandomizedSearchCV is a technique that searches over random combinations of hyperparameters to find the best model configuration using cross-validation making it more efficient than exclusice methods.

# %% [markdown]
# To optimize computation, we primarily use **RandomizedSearchCV**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier

X,y = make_classification(
    n_classes=2,
    n_informative=8,
    n_redundant=2,
    n_repeated=0,
    n_samples=1000,
    n_features=10,
    random_state=42,
    )

# %% [markdown]
# ### GridSearchCV:

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV( 
    DecisionTreeClassifier(),
    {
        'criterion' : ['gini', 'entropy'],
        'max_depth' : [5, 10, 15, 20]
    }, 
    cv = 5, 
    return_train_score= False
)

clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.007544      0.000848         0.001220        0.000268
# 1       0.010772      0.000780         0.001002        0.000005
# 2       0.011599      0.001021         0.001601        0.000801
# 3       0.010460      0.000824         0.001430        0.000382
# 4       0.011636      0.002250         0.001399        0.000483
# 5       0.014194      0.000981         0.001010        0.000006
# 6       0.014797      0.001165         0.001003        0.000005
# 7       0.014995      0.001096         0.001203        0.000402
#
#   param_criterion  param_max_depth                                     params  \
# 0            gini                5      {'criterion': 'gini', 'max_depth': 5}
# 1            gini               10     {'criterion': 'gini', 'max_depth': 10}
# 2            gini               15     {'criterion': 'gini', 'max_depth': 15}
# ...

# %% [markdown]
# As in grid search we had to calculate all of the permuation combinations which were 8 in this case. Which costs computation power. So to save computation power we use RandomizedSearchCV(). Which only calculates n_iter number of random combinations not all.

# %% [markdown]
# ### RandomizedSearchCV:

# %%
from sklearn.model_selection import RandomizedSearchCV

clf = RandomizedSearchCV( 
    DecisionTreeClassifier(),
    {
        'criterion' : ['gini', 'entropy'],
        'max_depth' : [5, 10, 15, 20]
    }, 
    cv = 5, 
    return_train_score= False,
    n_iter=3
)

clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.007647      0.000906         0.001109        0.000670
# 1       0.010822      0.001135         0.001399        0.000485
# 2       0.010403      0.001023         0.000997        0.000011
#
#    param_max_depth param_criterion                                    params  \
# 0                5            gini     {'max_depth': 5, 'criterion': 'gini'}
# 1               20            gini    {'max_depth': 20, 'criterion': 'gini'}
# 2                5         entropy  {'max_depth': 5, 'criterion': 'entropy'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.780              0.815              0.735              0.790
# 1              0.800              0.755              0.840              0.800
# 2              0.765              0.785              0.765              0.815
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# ...

# %% [markdown]
# As we can see that only random 3 of 8 combinations got calculated which saved a lot compuational power.

# %% [markdown]
# We can use all other methods of GridSearchCV as it is. Such as best_params, best_estimator, etc.

# %%
clf.best_params_
# Out:
# {'max_depth': 20, 'criterion': 'gini'}

# %%
clf.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=20)
