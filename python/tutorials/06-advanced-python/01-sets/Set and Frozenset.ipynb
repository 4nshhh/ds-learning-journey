# %%
myset = set([1,3,3,4,5,1])

# %%
myset
# Out:
# {1, 3, 4, 5}

# %%
myset = {1,2,3,4,5,2,3}
myset
# Out:
# {1, 2, 3, 4, 5}

# %%
menu = set(["Pizza","Burger","Samosa"])

# %%
menu.add("Idli")

# %%
menu
# Out:
# {'Burger', 'Idli', 'Pizza', 'Samosa'}

# %%
menu.remove("Samosa")

# %%
menu
# Out:
# {'Burger', 'Idli', 'Pizza'}

# %%
menu = frozenset(["Pizza","Burger","Samosa"])

# %%
menu.add("Idli")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 menu.add("Idli")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
"Pizza" in menu
# Out:
# True

# %%
"Idli" in menu
# Out:
# False

# %%
transactions = [
    {'customer_name': "Mira", "amount": 56, "date": "2024-08-01"},
    {'customer_name': "Mira", "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': "Mohan", "amount": 21, "date": "2024-09-03"},
    {'customer_name': "Mohan", "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': "Lucy", "amount": 66.3, "date": "2024-09-10"}
]

# %%
names = set()
for trans in transactions:
    names.add(trans["customer_name"])

# %%
names
# Out:
# {'Lucy', 'Mira', 'Mohan'}

# %%
names_list = list(names)
names_list
# Out:
# ['Mira', 'Lucy', 'Mohan']

# %%
a = {"Mira", "Mohan", "Lucy", "Ahmed"}
b = {"Chen", "Mohan", "Radha", "Maria"}

# %%
a.intersection(b)
# Out:
# {'Mohan'}

# %%
a.union(b)
# Out:
# {'Ahmed', 'Chen', 'Lucy', 'Maria', 'Mira', 'Mohan', 'Radha'}

# %%
a-b
# Out:
# {'Ahmed', 'Lucy', 'Mira'}

# %%
b-a
# Out:
# {'Chen', 'Maria', 'Radha'}
